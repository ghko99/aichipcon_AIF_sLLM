# %%
import pandas as pd
df = pd.read_csv("final_data.csv")
df
# Out:
#               번호  주택유형                                                공고명  \
# 0     59421911.0  국민임대          진주평거(고령자복지주택) 국민임대(스마트청년형) 자격완화 입주자 모집 공고
# 1     59357675.0  공공임대         수원역푸르지오자이 5년 공공임대주택 예비입주자 모집공고(2024.11.08)
# 2     59421956.0  국민임대                         익산한스빌 국민임대주택 예비입주자 완화 모집공고
# 3     59352140.0  공공임대        보령명천2 50년공공임대주택 예비입주자 모집공고(공고일:2024.11.07.)
# 4     59386427.0  국민임대                      [정정공고]남양주시 지역 국민임대주택 예비입주자 모집
# ...          ...   ...                                                ...
# 1238  55030298.0  국민임대                         화성남양뉴타운 B-10블록 대체공급 입주자 모집
# 1239  55025157.0  행복주택                        파주시 대체 임대주택 모집공고('23.11.08)
# 1240  55035503.0  행복주택                            평택소사벌 A-7블록 대체공급 입주자 모집
# 1241  55025049.0  공공임대  [정정공고]10년 공공임대 선착순 동호지정 입주자 모집공고(부산만덕5 2블럭 및 부...
# 1242  54942248.0  영구임대                        인천옹진연평 영구임대주택 입주자격완화 입주자 모집
#
#            지역       공고게시일         마감일  공고상태
# ...

# %%
missing_values_rows = df[df.isnull().any(axis=1)]
print("빈값이 포함된 행:")
print(missing_values_rows)
# Out:
# 빈값이 포함된 행:
#       번호 주택유형  공고명   지역 공고게시일  마감일 공고상태
# 341  NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 487  NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 557  NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 576  NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 603  NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 606  NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 623  NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 650  NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 656  NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 825  NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 999  NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1028 NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1048 NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1049 NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1051 NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1063 NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1064 NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1077 NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1126 NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1132 NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1163 NaN  NaN  NaN  NaN   NaN  NaN  NaN
# 1226 NaN  NaN  NaN  NaN   NaN  NaN  NaN

# %%
df = df.dropna()

# %%
missing_values_rows = df[df.isnull().any(axis=1)]
print("빈값이 포함된 행:")
print(missing_values_rows)
# Out:
# 빈값이 포함된 행:
# Empty DataFrame
# Columns: [번호, 주택유형, 공고명, 지역, 공고게시일, 마감일, 공고상태]
# Index: []

# %%
df.to_csv("final_data3.csv", index=False, encoding='utf-8')  # UTF-8-SIG로 한글 깨짐 방지
